# %%
import streamlit as st

# %%
import pandas as pd

# %%
import numpy as np

# %%
engie = pd.read_csv("ENGIY.csv")

# %%
engie
# Out:
#          Date   Open       High     Low  Close  Adj Close   Volume
# 0  2017-05-01  14.15  15.370000  14.110  15.31  13.168867  3100100
# 1  2017-06-01  15.30  15.820000  15.060  15.15  13.510805  2446400
# 2  2017-07-01  15.24  16.209999  14.760  16.16  14.411525  2909900
# 3  2017-08-01  16.15  17.219999  15.970  16.76  14.946607  3651100
# 4  2017-09-01  16.85  17.980000  16.000  16.98  15.142802  4011800
# ..        ...    ...        ...     ...    ...        ...      ...
# 56 2022-01-01  14.93  15.900000  14.740  15.38  15.380000  4242300
# 57 2022-02-01  15.59  16.780001  15.260  15.87  15.870000  2482400
# 58 2022-03-01  14.37  14.390000  10.770  13.10  13.100000  8422000
# 59 2022-04-01  13.23  13.250000  12.270  12.57  12.570000  3160900
# 60 2022-04-18  12.60  12.680000  12.418  12.60  12.600000   344775
#
# [61 rows x 7 columns]

# %%
engie['Date'].unique().tolist()
# Out:
# ['2017-05-01',
#  '2017-06-01',
#  '2017-07-01',
#  '2017-08-01',
#  '2017-09-01',
#  '2017-10-01',
#  '2017-11-01',
#  '2017-12-01',
#  '2018-01-01',
#  '2018-02-01',
#  '2018-03-01',
#  '2018-04-01',
#  '2018-05-01',
#  '2018-06-01',
#  '2018-07-01',
#  '2018-08-01',
#  '2018-09-01',
#  '2018-10-01',
#  '2018-11-01',
#  '2018-12-01',
#  '2019-01-01',
#  '2019-02-01',
#  '2019-03-01',
#  '2019-04-01',
#  '2019-05-01',
#  '2019-06-01',
#  '2019-07-01',
#  '2019-08-01',
#  '2019-09-01',
#  '2019-10-01',
#  '2019-11-01',
#  '2019-12-01',
#  '2020-01-01',
#  '2020-02-01',
#  '2020-03-01',
#  '2020-04-01',
#  '2020-05-01',
#  '2020-06-01',
#  '2020-07-01',
#  '2020-08-01',
#  '2020-09-01',
#  '2020-10-01',
#  '2020-11-01',
#  '2020-12-01',
#  '2021-01-01',
#  '2021-02-01',
#  '2021-03-01',
#  '2021-04-01',
#  '2021-05-01',
#  '2021-06-01',
#  '2021-07-01',
#  '2021-08-01',
#  '2021-09-01',
#  '2021-10-01',
#  '2021-11-01',
#  '2021-12-01',
#  '2022-01-01',
#  '2022-02-01',
# ...

# %%
engie["Date"] = engie["Date"].astype("datetime64")

# %%
engie.groupby(engie["Date"].dt.year).count().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
marketing = pd.read_csv("Données devoir SAS.csv")

# %%
marketing
# Out:
#      ID;annee_naissance;Niveau_educatif;Situation_maritale;Revenu;Nb_enfant;Nb_ado;date_ancienneté;NB_jours_achat;mt_vin;mt_fruit;mt_viande;mt_poisson;mt_bonbon;mt_or;nb_achat_discount;nb_achat_web;nb_achat_catalogue;nb_achat_magasin;nb_web_visite;offre_accepte_1;offre_accepte_2;offre_accepte_3;offre_accepte_4;offre_accepte_5;Plainte;Reponse
# 0     5524;1957;Graduation;Single;58138;0;0;04/09/20...
# 1     2174;1954;Graduation;Single;46344;1;1;08/03/20...
# 2     4141;1965;Graduation;Together;71613;0;0;21/08/...
# 3     6182;1984;Graduation;Together;26646;1;0;10/02/...
# 4     5324;1981;PhD;Married;58293;1;0;19/01/2014;94;...
# ...                                                 ...
# 2235  10870;1967;Graduation;Married;61223;0;1;13/06/...
# 2236  4001;1946;PhD;Together;64014;2;1;10/06/2014;56...
# 2237  7270;1981;Graduation;Divorced;56981;0;0;25/01/...
# 2238  8235;1956;Master;Together;69245;0;1;24/01/2014...
# 2239  9405;1954;PhD;Married;52869;1;1;15/10/2012;40;...
#
# ...

# %%
election = pd.read_csv("p2022-resultats-regions-t1.csv")

# %%
election
# Out:
#     CodeRégion                      Région  Inscrits  Abstentions  \
# 0           44                   Grand Est   3862920      1008344
# 1           75          Nouvelle-Aquitaine   4463041       962499
# 2           84        Auvergne-Rhône-Alpes   5557535      1228490
# 3           27     Bourgogne-Franche-Comté   1992409       456682
# 4           53                    Bretagne   2562061       543414
# 5           24         Centre-Val de Loire   1837328       459528
# 6           11               Île-de-France   7349284      1760727
# 7           76                   Occitanie   4323929       940541
# 8           32             Hauts-de-France   4255350      1146209
# 9           28                   Normandie   2413749       590804
# 10          52            Pays de la Loire   2832949       652018
# 11          93  Provence-Alpes-Côte d'Azur   3663871       959575
# 12          94                       Corse    243032        90629
# ...
