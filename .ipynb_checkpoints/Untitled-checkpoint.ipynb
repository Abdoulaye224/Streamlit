# %%
import streamlit as st

# %%
import pandas as pd

# %%
import numpy as np

# %%
engie = pd.read_csv("ENGIY.csv", index_col='Date')

# %%
engie
# Out:
#              Open   High    Low  Close  Adj Close   Volume
# Date
# 2017-05-01  14.15  14.23  14.11  14.21  11.318880    57400
# 2017-05-02  14.45  14.52  14.36  14.47  11.525982    68900
# 2017-05-03  14.43  14.64  14.39  14.59  11.621567    68200
# 2017-05-04  14.90  15.35  14.90  15.34  12.218973   140500
# 2017-05-05  15.03  15.37  15.02  15.37  12.242869    99400
# ...           ...    ...    ...    ...        ...      ...
# 2022-04-25  12.36  12.58  12.36  12.52  12.520000   403700
# 2022-04-26  12.39  12.49  12.12  12.16  12.160000   251700
# 2022-04-27  11.81  11.89  11.66  11.80  11.800000   210300
# 2022-04-28  11.90  12.08  11.87  12.06  12.060000  1079300
# 2022-04-29  12.02  12.08  11.80  11.86  11.860000   225200
#
# [1260 rows x 6 columns]

# %%
len(engie)
# Out:
# 1260

# %%
for i in range(0, len(engie)):
    engie['rent'][i]=(engie['Adj Close'][i+1]-engie['Adj Close'][i])/engie['Adj Close'][i]
# Out:
# <ipython-input-18-63950c674009>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   engie['rent'][i]=(engie['Adj Close'][i+1]-engie['Adj Close'][i])/engie['Adj Close'][i]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-63950c674009> in <module>
#       1 for i in range(1, len(engie)):
# ----> 2     engie['rent'][i]=(engie['Adj Close'][i+1]-engie['Adj Close'][i])/engie['Adj Close'][i]
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     848
#     849         if is_integer(key) and self.index._should_fallback_to_positional():
# --> 850             return self._values[key]
#     851
#     852         elif key_is_scalar:
#
# ...

# %%
engie
# Out:
#              Open   High    Low  Close  Adj Close   Volume      rent
# Date
# 2017-05-01  14.15  14.23  14.11  14.21  11.318880    57400  0.018297
# 2017-05-02  14.45  14.52  14.36  14.47  11.525982    68900  0.008293
# 2017-05-03  14.43  14.64  14.39  14.59  11.621567    68200  0.051405
# 2017-05-04  14.90  15.35  14.90  15.34  12.218973   140500  0.001956
# 2017-05-05  15.03  15.37  15.02  15.37  12.242869    99400 -0.013012
# ...           ...    ...    ...    ...        ...      ...       ...
# 2022-04-25  12.36  12.58  12.36  12.52  12.520000   403700 -0.028754
# 2022-04-26  12.39  12.49  12.12  12.16  12.160000   251700 -0.029605
# 2022-04-27  11.81  11.89  11.66  11.80  11.800000   210300  0.022034
# 2022-04-28  11.90  12.08  11.87  12.06  12.060000  1079300 -0.016584
# 2022-04-29  12.02  12.08  11.80  11.86  11.860000   225200 -0.016584
#
# [1260 rows x 7 columns]

# %%
engie.rename(columns = {'Adj Close':'AdjClose'}, inplace = True)

# %%
test = engie.pct_change()

# %%
rents = (engie.AdjClose[1:].values - engie.AdjClose[:-1].values)/engie.AdjClose[1:].values

# %%
rents = pd.Series(returns, index=engie.index[1:])

# %%
rents
# Out:
# Date
# 2017-05-02    0.017968
# 2017-05-03    0.008225
# 2017-05-04    0.048892
# 2017-05-05    0.001952
# 2017-05-08   -0.013184
#                 ...
# 2022-04-25    0.034744
# 2022-04-26   -0.029605
# 2022-04-27   -0.030508
# 2022-04-28    0.021559
# 2022-04-29   -0.016863
# Length: 1259, dtype: object

# %%
returns[]
# Out:
# 0.01796827376617461

# %%
#importation du fichier excel
df = pd.read_excel(
        io="./projet_streamlit.xlsx",
        engine="openpyxl",
        sheet_name="ENGIY",
        skiprows=0,
        usecols="A:K",
        nrows=62,
    )

# %%
df.rename(columns = {'Rentabilité mensuel':'rent_month', 'rentabilité moyenne annuel':'means_rent_year', "Volatilité annuel de l'action":'volatility'}, inplace = True)

# %%
df
# Out:
#          Date   Open       High     Low  Close  Adj Close   Volume  \
# 0  2017-05-01  14.15  15.370000  14.110  15.31  13.168867  3100100
# 1  2017-06-01  15.30  15.820000  15.060  15.15  13.510805  2446400
# 2  2017-07-01  15.24  16.209999  14.760  16.16  14.411525  2909900
# 3  2017-08-01  16.15  17.219999  15.970  16.76  14.946607  3651100
# 4  2017-09-01  16.85  17.980000  16.000  16.98  15.142802  4011800
# ..        ...    ...        ...     ...    ...        ...      ...
# 56 2022-01-01  14.93  15.900000  14.740  15.38  15.380000  4242300
# 57 2022-02-01  15.59  16.780001  15.260  15.87  15.870000  2482400
# 58 2022-03-01  14.37  14.390000  10.770  13.10  13.100000  8422000
# 59 2022-04-01  13.23  13.250000  12.270  12.57  12.570000  3160900
# 60 2022-04-18  12.60  12.680000  12.418  12.60  12.600000   344775
#
#     rent_month  means_rent_year  volatility  Dividends
# 0          NaN              NaN         NaN        0.5
# ...

# %%
df['DATE'] = df['Date'].apply(lambda x: x.strftime('%Y-%m-%d'))

# %%
data_renta_mens = df[['Date','rent_month']].dropna()
# Out:
# 2022-05-12 23:13:41.844 INFO    numexpr.utils: NumExpr defaulting to 8 threads.

# %%
data_renta_mens
# Out:
#          Date  rent_month
# 1  2017-06-01    0.025966
# 2  2017-07-01    0.066667
# 3  2017-08-01    0.037129
# 4  2017-09-01    0.013126
# 5  2017-10-01    0.000000
# 6  2017-11-01    0.028269
# 7  2017-12-01   -0.016609
# 8  2018-01-01    0.013978
# 9  2018-02-01   -0.098794
# 10 2018-03-01    0.072020
# 11 2018-04-01    0.045184
# 12 2018-05-01   -0.099545
# 13 2018-06-01   -0.007564
# 14 2018-07-01    0.054178
# 15 2018-08-01   -0.097833
# 16 2018-09-01    0.002059
# 17 2018-10-01   -0.091781
# 18 2018-11-01    0.092477
# 19 2018-12-01    0.018492
# 20 2019-01-01    0.124302
# 21 2019-02-01   -0.068323
# 22 2019-03-01   -0.008667
# 23 2019-04-01   -0.004707
# 24 2019-05-01   -0.062838
# 25 2019-06-01    0.153881
# 26 2019-07-01    0.012599
# 27 2019-08-01   -0.009168
# 28 2019-09-01    0.076669
# 29 2019-10-01    0.030080
# 30 2019-11-01   -0.063170
# 31 2019-12-01    0.028626
# 32 2020-01-01    0.059369
# 33 2020-02-01   -0.026853
# 34 2020-03-01   -0.388122
# ...

# %%
data_renta_mens['rent_month'][1]
# Out:
# 0.025965635464311316

# %%
data_renta_moy_an = df[['Date','means_rent_year']].dropna()

# %%
data_renta_moy_an
# Out:
#          Date  means_rent_year
# 7  2017-12-01         0.022078
# 19 2018-12-01        -0.008094
# 31 2019-12-01         0.017440
# 43 2020-12-01         0.007142
# 55 2021-12-01        -0.001511
# 60 2022-04-18        -0.011680

# %%
Volatilite=df[['Date','volatility']].dropna()

# %%
Volatilite
# Out:
#          Date  volatility
# 7  2017-12-01    0.879012
# 19 2018-12-01    1.041233
# 31 2019-12-01    1.102291
# 43 2020-12-01    2.162786
# 55 2021-12-01    0.681342
# 60 2022-04-18    1.594531

# %%
Dividends=df[['Date', 'Dividends']].dropna()

# %%
Dividends
# Out:
#          Date  Dividends
# 0  2017-05-01       0.50
# 5  2017-10-01       0.35
# 17 2018-10-01       0.37
# 24 2019-05-01       0.37
# 36 2020-05-01       0.80
# 48 2021-05-01       0.53
